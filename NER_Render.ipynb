# %%
import spacy
import os
import re
import shutil
import csv
from spacy import displacy

# %%
# Load pretrained custom model
nlp = spacy.load("M:/Projekt/HortiSem/tmp_model_v2")

# %%
text = "Kohlgemüse: In Winterraps wurden bereits örtlich stärkere Akivitäten von Rapsstängelrüsslern beobachtetet. Bei weiterer Erwärmung besteht in den kommenden Wochen auch für Kohlbestände hohe Befallsgefahr, v.a. in der Nähe von Rapsflächen (einschl. Vorjahresflächen).  Bestände unter Vliesabdeckung sind vor Befall geschützt, wenn das Vlies gleich nach der Pflanzung aufgelegt wurde.  Zur Kontrolle des Zufluges von Rapsstängel- und Kohltriebrüsslern sowie Rapsglanzkäfern sollten Gelbschalen, befüllt mit Wasser und einigen Tropfen Geschirrspülmittel, aufgestellt werden (auch Bestände in Folienzelten/Gewächshäusern). Werden innerhalb von 3 Tagen mehr als 10 Rüsselkäfer/Schale gefangen, sind Insektizidmaßnahmen erforderlich (einsetzbare Präparate, siehe www.isip.de/psd-bb) Gelbschale zur Überwachung von Kohlschädlingen    Zulassungsinformationen Zulassungsverlängerung (Hauptzulassung) Delan WG (Dithianon)    verlängert bis 30.09. 2017 Lentagran WP (Pyridat)    verlängert bis 31.05. 2017 Ratron Giftweizen u.a. (Zinkphosphid)  verlängert bis 31.12. 2017"
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text)
# Out:
# Kohlgemüse
# Winterraps
# Rapsstängelrüsslern
# Kohlbestände
# Rapsflächen
# Vlies
# Zufluges
# Rapsstängel- und Kohltriebrüsslern
# Rapsglanzkäfern
# Folienzelten
# Delan WG
# Lentagran WP
# Zinkphosphid

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="25dd1c5498974035bf8a6d125376ec48-0" class="displacy" width="22450" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Kohlgemüse:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
# ...

# %%
colors = {"Kultur": "#33ff3c", 
          "Erreger": " #e0ff33 ",
          "Mittel":" #333cff ", 
          "Ort":" #a233ff ",
          "Zeit": " #19c5e8 ",
          "Auftreten": " #e81948 ",
          "BBCH_Stadium":" #d0f998 ",
          "Witterung": " #fc9ce7"}
options = {"ents": ["Kultur", "Erreger","Mittel", "Ort","Zeit","Auftreten","BBCH_Stadium","Witterung"], "colors": colors}

# %%
# Entity types in uppercase
colors = {"KULTUR": "#33ff3c", 
          "ERREGER": " #e0ff33 ",
          "MITTEL":"  #98d7f9  ", 
          "ORT":" #a233ff ",
          "ZEIT": " #19c5e8 ",
          "AUFTRETEN": "  #f998d1  ",
          "BBCH_STADIUM":" #d0f998 ",
          "WITTERUNG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"ents": ["KULTUR", "ERREGER","MITTEL", "ORT","ZEIT","AUFTRETEN","BBCH_STADIUM","WITTERUNG"], "colors": colors}

# %%
# Visualize the entity in the text
displacy.render(doc, style="ent", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #33ff3c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kohlgemüse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Kultur</span>
# </mark>
# : In
# <mark class="entity" style="background: #33ff3c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterraps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Kultur</span>
# </mark>
#  wurden bereits örtlich stärkere Akivitäten von
# <mark class="entity" style="background:  #e0ff33 ; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rapsstängelrüsslern
# ...
